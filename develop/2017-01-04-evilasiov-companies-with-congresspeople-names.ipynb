# %% [markdown]
# # Look for companies with congresspeople names
#
# Sometimes the trade company name is the owner's name, specially when it has just a single parter. Searching for these companies (possibly filtering by legal_entity equals to 213-5 - EMPRESARIO (INDIVIDUAL)) may bring good results.

# %%
from serenata_toolbox.datasets import fetch

fetch('2016-12-06-reimbursements.xz', '../data')
fetch('2016-09-03-companies.xz', '../data')
fetch('2016-12-21-deputies.xz', '../data')

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('../data/2016-12-06-reimbursements.xz',
                   dtype={'cnpj_cpf': np.str},
                   low_memory=False)

# %%
data['supplier'].unique()
# Out:
# array(['MELHOR POSTO DE COMBUSTÍVEIS LTDA', 'MELONGENA PARTICIPAÇÕES LTDA',
#        'ARY ANTONIO MOSCHETTA', ..., 'hotel restaurante lancheria do NENE',
#        'EDGAR LISBOA - ME', 'ZERO QUINZE'], dtype=object)

# %%
data['congressperson_name'].unique()
# Out:
# array(['DILCEU SPERAFICO', 'DOMINGOS DUTRA', 'EDINHO BEZ', ...,
#        'MOISÉS DINIZ', 'RICARDO BENTINHO', 'TAMPINHA'], dtype=object)

# %%
deputies = pd.read_csv('../data/2016-12-21-deputies.xz',
                       usecols=['congressperson_id', 'civil_name'])
deputies.head()
# Out:
#    congressperson_id                  civil_name
# 0              81366  LUANA MARIA DA SILVA COSTA
# 1             178980    ANTONIO GOULART DOS REIS
# 2             141335  JOSÉ ROBERTO OLIVEIRA FARO
# 3             141531   RODRIGO BATISTA DE CASTRO
# 4             141478   LAERTE RODRIGUES DE BESSA

# %% [markdown]
# Looking for exact matches of names (in supplier names).

# %%
import unicodedata

def normalize_string(string):
    if isinstance(string, str):
        nfkd_form = unicodedata.normalize('NFKD', string.lower())
        return nfkd_form.encode('ASCII', 'ignore').decode('utf-8')

# %%
data.congressperson_name = data.congressperson_name.apply(normalize_string)
data.supplier = data.supplier.apply(normalize_string)
deputies.civil_name = deputies.civil_name.apply(normalize_string)

# %%
supplier_has_congressperson_name = \
    data['supplier'].isin(deputies['civil_name'])
data.loc[supplier_has_congressperson_name,
                   ['issue_date', 'congressperson_name', 'supplier', 'subquota_description', 'cnpj_cpf', 'document_id', 'total_net_value']]
# Out:
#                  issue_date congressperson_name  \
# 200406  2010-12-28T00:00:00      marcelo castro
# 204127  2010-08-27T00:00:00     paulo magalhaes
# 233647  2010-07-06T00:00:00       carlos manato
# 233652  2010-07-19T00:00:00       carlos manato
# 295219  2010-01-25T00:00:00        laerte bessa
# 295220  2010-01-29T00:00:00        laerte bessa
# 296568  2010-10-12T00:00:00        lelo coimbra
# 341245  2010-01-06T00:00:00          maia filho
# 376127  2010-10-02T00:00:00    darcisio perondi
# 376128  2010-10-02T00:00:00    darcisio perondi
# 376129  2010-10-02T00:00:00    darcisio perondi
# 492105  2011-08-02T00:00:00      domingos savio
# 571851  2011-12-23T00:00:00     lideranca do pt
# 695791  2012-04-26T00:00:00         zeca dirceu
#
#                                       supplier  \
# 200406                  marcelo costa e castro
# 204127      paulo sergio paranhos de magalhaes
# 233647                 carlos humberto mannato
# 233652                 carlos humberto mannato
# 295219               laerte rodrigues de bessa
# 295220               laerte rodrigues de bessa
# 296568                       welington coimbra
# 341245              jose de andrade maia filho
# 376127                  darcisio paulo perondi
# 376128                  darcisio paulo perondi
# 376129                  darcisio paulo perondi
# 492105           domingos savio campos resende
# 571851            luiz paulo teixeira ferreira
# 695791  jose carlos becker de oliveira e silva
#
#                                      subquota_description        cnpj_cpf  \
# 200406                                     Flight tickets  04114985000137
# 204127           Consultancy, research and technical work  06253998000112
# 233647                                  Telecommunication  04164616000159
# 233652   Automotive vehicle renting or watercraft charter     57480788720
# 295219                                     Flight tickets  07575651000159
# 295220                                     Flight tickets  07575651000159
# 296568                                     Flight tickets     34318100715
# 341245  Lodging, except for congressperson from Distri...  09967852007563
# 376127                                  Telecommunication     08262748034
# 376128                                  Telecommunication     08262748034
# 376129                                  Telecommunication     08262748034
# 492105                                     Flight tickets     22275150668
# 571851           Consultancy, research and technical work  03606027000110
# 695791                                     Flight tickets  02012862000160
#
#         document_id  total_net_value
# 200406      1985323         12000.00
# 204127      1919603          8900.00
# 233647      1893988           361.92
# 233652      1894078          4500.00
# 295219      1763526           667.52
# 295220      1763527           774.52
# 296568      1944297           614.42
# 341245      1775596           216.00
# 376127      1941983           483.59
# 376128      1941996           301.42
# 376129      1941999           614.16
# 492105      2129592           335.51
# 571851      2234319           947.92
# 695791      2351701            30.00

# %%
companies = pd.read_csv('../data/2016-09-03-companies.xz', low_memory=False)

# %%
companies['cnpj'].head()
# Out:
# 0    05.939.467/0001-15
# 1    16.571.066/0001-71
# 2    07.069.926/0001-82
# 3    05.246.123/0001-20
# 4    04.606.157/0001-16
# Name: cnpj, dtype: object

# %%
companies['cnpj'] = companies['cnpj'].str.replace(r'[\.\/\-]', '')

# %%
data = pd.merge(data, companies,
       how='left',
       left_on='cnpj_cpf',
       right_on='cnpj')

# %%
data.name = data.name.apply(normalize_string)
data.trade_name = data.trade_name.apply(normalize_string)

# %%
suspect_row = data.supplier.isin(deputies['civil_name']) | data.name.isin(deputies['civil_name']) | data.trade_name.isin(deputies['civil_name']) 
data[suspect_row].shape
# Out:
# (14, 259)

# %%
import re

regex = re.compile(r'(?:{})'.format('|'.join(deputies.civil_name)))
rows = data.supplier.apply(lambda name: regex.search(name) is not None)
data[rows].shape
# Out:
# (72, 259)

# %%
data.loc[rows,
         ['issue_date', 'congressperson_name', 'supplier', 'subquota_description', 'cnpj_cpf', 'document_id', 'total_net_value']]
# Out:
#                   issue_date         congressperson_name  \
# 73923    2009-06-06T00:00:00                 afonso hamm
# 73924    2009-05-26T00:00:00                 afonso hamm
# 73925    2009-05-26T00:00:00                 afonso hamm
# 74332    2009-10-03T00:00:00                 afonso hamm
# 200406   2010-12-28T00:00:00              marcelo castro
# 1393591  Lodging, except for congressperson from Distri...  92209790000138
# 1529752                                Congressperson meal  77888881000153
# 1530140  Lodging, except for congressperson from Distri...  92209790000138
#
#          document_id  total_net_value
# 73923        1603993           207.67
# 73924        1604000           101.68
# 73925        1604001           129.42
# 74332        1689370            89.25
# 200406       1985323         12000.00
# 204127       1919603          8900.00
# 215985       1839872           103.70
# 233647       1893988           361.92
# 233652       1894078          4500.00
# 255746       1803098           236.48
# 255873       1830066           175.80
# 256045       1850567           100.55
# 256290       1900932            88.55
# 256308       1909572           258.11
# 256328       1922951           258.11
# 256359       1938624           226.24
# 285424       1898819            89.25
# 295219       1763526           667.52
# 295220       1763527           774.52
# 296568       1944297           614.42
# 341245       1775596           216.00
# 376127       1941983           483.59
# 376128       1941996           301.42
# 376129       1941999           614.16
# 416889       2171818           154.50
# 427881       1999813           148.93
# 427969       2018018           225.12
# 432086       2221748           344.02
# 492105       2129592           335.51
# 495383       2072379            69.65
# ...              ...              ...
# 698180       2276733           342.00
# 698184       2276751             2.50
# 758571       2443187           136.20
# 758572       2443190           162.00
# 813027       5225858            82.00
# 813028       5225871            82.00
# 813350       5283274           102.00
# 836188       5092475           696.00
# 836189       5092478           696.00
# 836190       5092498           696.00
# 839636       5134625           332.00
# 839766       5179029           407.00
# 840173       5303182           264.00
# 888770       5129670            88.00
# 922438       5054687           164.00
# 1023597      5327821           679.00
# 1025694      5364499           410.00
# 1025984      5468283           298.00
# 1026166      5581742           261.00
# 1081649      5525528            25.00
# 1171982      5678440           481.00
# 1188632      5681455           413.00
# 1189044      5869125           359.00
# 1235737      5790439            36.50
# 1291129      5767733           150.00
# 1387978      6101207           225.00
# 1387981      6101235           149.00
# 1393591      6096523           231.00
# 1529752      6017310            26.50
# 1530140      6102209           374.00
#
# [72 rows x 7 columns]

# %%
deputies[deputies.civil_name == 'joao rodrigues']
# Out:
#      congressperson_id      civil_name
# 240             160571  joao rodrigues

# %% [markdown]
# So far we've been searching for congresspeople putting money in others' companies. When paying for a non-relative congressperson may be legal, but could raise corruption suspicions when combined with other irregularities.

# %%
data = pd.merge(data, deputies, how='left')

# %%
d = data.head()
rows = (data['supplier'] == data['civil_name']) | (data['supplier'] == data['congressperson_name'])
data.loc[rows,
         ['issue_date', 'congressperson_name', 'supplier', 'subquota_description', 'cnpj_cpf', 'document_id', 'total_net_value']]
# Out:
#                  issue_date    congressperson_name  \
# 41376   2009-06-22T00:00:00         assis do couto
# 92265   2009-08-12T00:00:00           efraim filho
# 92432   2009-07-25T00:00:00          elismar prado
# 182438  2010-06-07T00:00:00          arnon bezerra
# 200406  2010-12-28T00:00:00         marcelo castro
# 204127  2010-08-27T00:00:00        paulo magalhaes
# 233647  2010-07-06T00:00:00          carlos manato
# 233652  2010-07-19T00:00:00          carlos manato
# 295219  2010-01-25T00:00:00           laerte bessa
# 295220  2010-01-29T00:00:00           laerte bessa
# 296568  2010-10-12T00:00:00           lelo coimbra
# 322194  2010-12-20T00:00:00          sueli vidigal
# 329507  2010-06-28T00:00:00   wandenkolk goncalves
# 341245  2010-01-06T00:00:00             maia filho
# 352401  2010-05-25T00:00:00       roberto balestra
# 357224  2010-09-09T00:00:00           osvaldo reis
# 370079  2010-11-23T00:00:00        abelardo lupion
# 376127  2010-10-02T00:00:00       darcisio perondi
# 376128  2010-10-02T00:00:00       darcisio perondi
# 376129  2010-10-02T00:00:00       darcisio perondi
# 419169  2011-11-25T00:00:00        geraldo resende
# 447173  2011-07-22T00:00:00         gladson cameli
# 447175  2011-07-15T00:00:00         gladson cameli
# 471483  2011-04-01T00:00:00  sabino castelo branco
# 482319  2011-03-01T00:00:00            neri geller
# 486600  2011-01-04T00:00:00          andre montoro
# 492105  2011-08-02T00:00:00         domingos savio
# 507298  2011-10-27T00:00:00           edmar arruda
# 549986  2011-02-01T00:00:00        luciano moreira
# 552237  2011-02-28T00:00:00      erivelton santana
# 568079  2011-02-07T00:00:00    mauricio dziedricki
# 573893  2011-02-23T00:00:00       roberto balestra
# 601842  2012-10-17T00:00:00         roberto freire
# 647608  2012-09-14T00:00:00            camilo cola
# 695791  2012-04-26T00:00:00            zeca dirceu
# 755752  2012-05-11T00:00:00            erika kokay
# 755775  2012-06-15T00:00:00            erika kokay
# 755778  2012-06-15T00:00:00            erika kokay
# 755797  2012-08-14T00:00:00            erika kokay
# 755798  2012-08-14T00:00:00            erika kokay
# 760330  2012-05-06T00:00:00          hugo napoleao
# 760331  2012-05-06T00:00:00          hugo napoleao
#
#                                       supplier  \
# 41376                           assis do couto
# 92265                             efraim filho
# 92432                            elismar prado
# 182438                           arnon bezerra
# 200406                  marcelo costa e castro
# 204127      paulo sergio paranhos de magalhaes
# 233647                 carlos humberto mannato
# 233652                 carlos humberto mannato
# 295219               laerte rodrigues de bessa
# 295220               laerte rodrigues de bessa
# 296568                       welington coimbra
# 322194                           sueli vidigal
# 329507                    wandenkolk goncalves
# 341245              jose de andrade maia filho
# 352401                        roberto balestra
# 357224                            osvaldo reis
# 370079                         abelardo lupion
# 376127                  darcisio paulo perondi
# 376128                  darcisio paulo perondi
# 376129                  darcisio paulo perondi
# 419169                         geraldo resende
# 447173                          gladson cameli
# 447175                          gladson cameli
# 471483                   sabino castelo branco
# 482319                             neri geller
# 486600                           andre montoro
# 492105           domingos savio campos resende
# 507298                            edmar arruda
# 549986                         luciano moreira
# 552237                       erivelton santana
# 568079                     mauricio dziedricki
# 573893                        roberto balestra
# 601842                          roberto freire
# 647608                             camilo cola
# 695791  jose carlos becker de oliveira e silva
# 755752                             erika kokay
# 755775                             erika kokay
# 755778                             erika kokay
# 755797                             erika kokay
# 755798                             erika kokay
# 760330                           hugo napoleao
# 760331                           hugo napoleao
#
#                                      subquota_description        cnpj_cpf  \
# 41376                                   Telecommunication  76535764000143
# 92265                                      Flight tickets  02012862000160
# 92432                                      Flight tickets  02428624000130
# 182438                                  Telecommunication  01009686007904
# 200406                                     Flight tickets  04114985000137
# 204127           Consultancy, research and technical work  06253998000112
# 233647                                  Telecommunication  04164616000159
# 233652   Automotive vehicle renting or watercraft charter     57480788720
# 295219                                     Flight tickets  07575651000159
# 295220                                     Flight tickets  07575651000159
# 296568                                     Flight tickets     34318100715
# 322194                                     Flight tickets     45103305704
# 329507                                     Flight tickets  02712394000136
# 341245  Lodging, except for congressperson from Distri...  09967852007563
# 352401                                Congressperson meal  37329513000150
# 357224           Consultancy, research and technical work  11819468000129
# 370079                                Congressperson meal  10542662000147
# 376127                                  Telecommunication     08262748034
# 376128                                  Telecommunication     08262748034
# 376129                                  Telecommunication     08262748034
# 419169                                     Flight tickets  02575829000148
# 447173                                  Telecommunication  02449992009625
# 447175                                     Flight tickets  84316421000116
# 471483                                     Flight tickets     22949461204
# 482319                                Congressperson meal  01410280000330
# 486600                                     Flight tickets  01832635000118
# 492105                                     Flight tickets     22275150668
# 507298                                     Flight tickets  02012862001050
# 549986                                     Flight tickets     04677358320
# 552237                               Fuels and lubricants     22989250549
# 568079                                     Flight tickets  07575651000159
# 573893                                Congressperson meal  09054158000119
# 601842                                     Flight tickets  02012862000160
# 647608                                     Flight tickets  02012862000160
# 695791                                     Flight tickets  02012862000160
# 755752                                     Flight tickets     22441107100
# 755775                                     Flight tickets  07575651000159
# 755778                                     Flight tickets  07575651000159
# 755797   Automotive vehicle renting or watercraft charter     22441107100
# 755798  Lodging, except for congressperson from Distri...     22441107100
# 760330                                     Flight tickets  02012862000160
# 760331                                     Flight tickets  02012862000160
#
#         document_id  total_net_value
# 41376       1618678           930.52
# 92265       1674474          1049.00
# 92432       1690970           290.00
# 182438      1887507           961.66
# 200406      1985323         12000.00
# 204127      1919603          8900.00
# 233647      1893988           361.92
# 233652      1894078          4500.00
# 295219      1763526           667.52
# 295220      1763527           774.52
# 296568      1944297           614.42
# 322194      1980092           548.42
# 329507      1885944          3500.00
# 341245      1775596           216.00
# 352401      1855261            40.22
# 357224      1921692          9000.00
# 370079      1962945           337.48
# 376127      1941983           483.59
# 376128      1941996           301.42
# 376129      1941999           614.16
# 419169      2210046           421.23
# 447173      2124319           558.03
# 447175      2124473           600.00
# 471483      2041689         25320.00
# 482319      2018615            38.50
# 486600      1987856           867.24
# 492105      2129592           335.51
# 507298      2208426           381.66
# 549986      2002836           389.02
# 552237      2020304           100.00
# 568079      2005285           584.02
# 573893      2013686           133.65
# 601842      2415333          1142.92
# 647608      2398333           402.13
# 695791      2351701            30.00
# 755752      2339892           686.04
# 755775      2347187           723.47
# 755778      2352897           395.57
# 755797      2376750            97.21
# 755798      2376754           258.72
# 760330      2318028           414.00
# 760331      2318032           527.00

# %% [markdown]
# In the previous query, many rows are false positives, given mistakes filling the form. Despite of CNPJ number is right, the supplier field was registered incorrectly, using the congressperson name.
